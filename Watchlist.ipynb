# %% [markdown]
# Picking Up the dataframe with the watchlist

# %%
from pathlib import Path
import pandas as pd

watchlist_path = Path("data/watchlist.csv")
watchlist_df = pd.read_csv(watchlist_path)

# %% [markdown]
# Showing the dataframe

# %%
print(watchlist_df.to_string())
# Out:
#            Date                                             Name  Year        Letterboxd URI
# 0    2024-03-15                          The Wolf of Wall Street  2013  https://boxd.it/3C1m
# 1    2024-03-17                                    The Holdovers  2023  https://boxd.it/vHza
# 2    2024-06-10                            Bad Boys: Ride or Die  2024  https://boxd.it/l3Ki
# 3    2024-06-10                               Godzilla Minus One  2023  https://boxd.it/zu4c
# 4    2024-06-10                               Planet of the Apes  1968  https://boxd.it/29p8
# 5    2024-06-10                                        Inception  2010  https://boxd.it/1skk
# 6    2024-06-10                                      Oppenheimer  2023  https://boxd.it/wUow
# 7    2024-06-10                                      Glass Onion  2022  https://boxd.it/oCkK
# 8    2024-06-10                      Ghostbusters: Frozen Empire  2024  https://boxd.it/AxYu
# 9    2024-06-10                                 American Fiction  2023  https://boxd.it/DYHm
# 10   2024-06-10                                       Madame Web  2024  https://boxd.it/nwD0
# 11   2024-06-10                                Anatomy of a Fall  2023  https://boxd.it/yuDE
# 12   2024-06-10                                       Past Lives  2023  https://boxd.it/oNB8
# 13   2024-06-10                                         Saltburn  2023  https://boxd.it/z4eg
# 14   2024-06-10                       Killers of the Flower Moon  2023  https://boxd.it/gHp0
# 15   2024-06-10            Indiana Jones and the Dial of Destiny  2023  https://boxd.it/b8vM
# 16   2024-06-10              Transformers: Revenge of the Fallen  2009  https://boxd.it/20gG
# 17   2024-06-10                   Transformers: Dark of the Moon  2011  https://boxd.it/16aC
# 18   2024-06-10                  Transformers: Age of Extinction  2014  https://boxd.it/3d1m
# 19   2024-06-10                    Transformers: The Last Knight  2017  https://boxd.it/b8xo
# 20   2024-06-10                                        Bumblebee  2018  https://boxd.it/f21O
# 21   2024-06-10                 Transformers: Rise of the Beasts  2023  https://boxd.it/oQTa
# 22   2024-06-10                                    Asteroid City  2023  https://boxd.it/s3ds
# 23   2024-06-10                                      Challengers  2024  https://boxd.it/zld0
# 24   2024-06-10                                            Creed  2015  https://boxd.it/a2qk
# 25   2024-06-10                                        Creed III  2023  https://boxd.it/pf68
# 26   2024-06-10                                         Creed II  2018  https://boxd.it/hgl8
# 27   2024-06-10                             John Wick: Chapter 4  2023  https://boxd.it/mh48
# 28   2024-06-10                         Avatar: The Way of Water  2022  https://boxd.it/2E2E
# 29   2024-06-10                                   Enola Holmes 2  2022  https://boxd.it/vfDe
# 30   2024-06-10                                 What Is a Woman?  2022  https://boxd.it/A8UM
# 31   2024-06-10                                Top Gun: Maverick  2022  https://boxd.it/cjr4
# 32   2024-06-10                                     The Northman  2022  https://boxd.it/nK2s
# 33   2024-06-10      Fantastic Beasts: The Secrets of Dumbledore  2022  https://boxd.it/bg8Q
# 34   2024-06-10                                    The Last Duel  2021  https://boxd.it/mQbe
# 158  2025-07-26                                     The Terminal  2004  https://boxd.it/2a2O
# 159  2025-07-26                      We Need to Talk About Kevin  2011  https://boxd.it/2pTS
# 160  2025-08-04                                  Happy Gilmore 2  2025  https://boxd.it/M8PQ
# 161  2025-08-05                             Being John Malkovich  1999  https://boxd.it/2ahu
# 162  2025-08-17                                     Raising Cain  1992  https://boxd.it/1P5C
# 163  2025-08-29                                   The Blue Trail  2025  https://boxd.it/IrKi
# 164  2025-09-21                                        Eddington  2025  https://boxd.it/o6MC
# 165  2025-09-22                                            Manas  2024  https://boxd.it/LPz0
# 166  2025-10-01                                The Hateful Eight  2015  https://boxd.it/8gw8
# 167  2025-10-01                                            Thief  1981  https://boxd.it/1TEc
# 168  2025-10-06                                      After Hours  1985  https://boxd.it/1VfS
# 169  2025-10-06                                Gangs of New York  2002  https://boxd.it/25FG
# 170  2025-10-06                                        Cape Fear  1991  https://boxd.it/28vu
# 171  2025-10-12                              Requiem for a Dream  2000  https://boxd.it/29VI
# 172  2025-10-16                                       Hard Labor  2011  https://boxd.it/3km2
# 173  2025-10-17                             The Red Light Bandit  1968  https://boxd.it/5ESQ
# 174  2025-10-20                                    Black Phone 2  2025  https://boxd.it/JpbW
# 175  2025-10-20                                      Lord of War  2005  https://boxd.it/284y
# 176  2025-10-20                                         Deep End  1970   https://boxd.it/i8m
# 177  2025-10-20                        A Nightmare on Elm Street  1984  https://boxd.it/2aw0
# 178  2025-10-21                        I Love You Phillip Morris  2009  https://boxd.it/1ZvK
# 179  2025-10-31                                         Good Boy  2025  https://boxd.it/SC0q
# 180  2025-11-01                     The Texas Chain Saw Massacre  1974  https://boxd.it/1lcS
# 181  2025-11-03                          The Blair Witch Project  1999  https://boxd.it/26ua
# 182  2025-11-03                                          Inferno  1980  https://boxd.it/1KbK
# 183  2025-11-03                                  Friday the 13th  1980  https://boxd.it/24fs
# 184  2025-11-03                                        The Witch  2015  https://boxd.it/9X0m
# 185  2025-11-03                                           Carrie  1976  https://boxd.it/20ZQ
# 186  2025-11-08                                          Bugonia  2025  https://boxd.it/qeWY
# 187  2025-11-16                                            Speed  1994  https://boxd.it/28qk
# 188  2025-11-21                                Dog Day Afternoon  1975  https://boxd.it/29bg
# 189  2025-11-24                               Memories of Murder  2003  https://boxd.it/1TSo

# %% [markdown]
# Rename incompatible movie names

# %%
watchlist_df["Name"] = watchlist_df["Name"].str.replace("Fake Blonde","Falsa Loura",regex=False)
watchlist_df["Name"] = watchlist_df["Name"].str.replace("Horizon: An American Saga – Chapter 2", "Horizon: An American Saga - Chapter 2")
watchlist_df["Name"] = watchlist_df["Name"].str.replace("Rio, 100 Degrees F°", "Rio, 40 Degrees")
watchlist_df["Name"] = watchlist_df["Name"].str.replace("F1", "F1: The Movie")
watchlist_df["Name"] = watchlist_df["Name"].str.replace("The Blue Trail", "The Blue Trail")

watchlist_df.to_csv(watchlist_path, index=False)

# %% [markdown]
# Searching and put all extra info about the movies into df

# %%
import requests
import traceback

# URL base da API
BASE_URL = "http://www.omdbapi.com/"

if watchlist_df.empty:
    print("There are no new movies to process. Exiting.")

else:
    for i, row in watchlist_df.iterrows():
        params = {"apikey": "77055a01", "t": row["Name"]}
        try:
            response = requests.get(BASE_URL, params=params)
            data = response.json()

            print(f"Processando filme {i}: {row['Name']}")

            # Verificando se o título retornado pela API corresponde
            if "Title" in data and row["Name"].lower() == data["Title"].lower():
                watchlist_df.loc[i, "Genre"] = data.get("Genre", "")
                watchlist_df.loc[i, "Director"] = data.get("Director", "")
                watchlist_df.loc[i, "Writer"] = data.get("Writer", "")
                watchlist_df.loc[i, "Actors"] = data.get("Actors", "")
                watchlist_df.loc[i, "Language"] = data.get("Language", "")
                watchlist_df.loc[i, "Country"] = data.get("Country", "")
                watchlist_df.loc[i, "Poster"] = data.get("Poster", "")
                print(f"Informações adicionadas com sucesso para o filme: {row['Name']}\n")
            else:
                print(f"\n ******** Título não corresponde ou não encontrado: {row['Name']} != {data.get('Title', 'N/A')} ******* \n")
        except Exception as e:
            print(f"Erro no índice {i}: {e}")
            print("Traceback:")
            traceback.print_exc()
# Out:
# Processando filme 0: The Wolf of Wall Street
# Informações adicionadas com sucesso para o filme: The Wolf of Wall Street
#
# Processando filme 1: The Holdovers
# Informações adicionadas com sucesso para o filme: The Holdovers
#
# Processando filme 2: Bad Boys: Ride or Die
# Informações adicionadas com sucesso para o filme: Bad Boys: Ride or Die
#
# Processando filme 3: Godzilla Minus One
# Informações adicionadas com sucesso para o filme: Godzilla Minus One
#
# Processando filme 4: Planet of the Apes
# Informações adicionadas com sucesso para o filme: Planet of the Apes
#
# Processando filme 5: Inception
# Informações adicionadas com sucesso para o filme: Inception
#
# Processando filme 6: Oppenheimer
# Informações adicionadas com sucesso para o filme: Oppenheimer
#
# Processando filme 7: Glass Onion
# Informações adicionadas com sucesso para o filme: Glass Onion
#
# Processando filme 8: Ghostbusters: Frozen Empire
# Informações adicionadas com sucesso para o filme: Ghostbusters: Frozen Empire
#
# Processando filme 9: American Fiction
# Informações adicionadas com sucesso para o filme: American Fiction
#
# Processando filme 10: Madame Web
# Informações adicionadas com sucesso para o filme: Madame Web
#
# Processando filme 11: Anatomy of a Fall
# Informações adicionadas com sucesso para o filme: Anatomy of a Fall
#
# Processando filme 12: Past Lives
# Informações adicionadas com sucesso para o filme: Past Lives
#
# Processando filme 13: Saltburn
# Informações adicionadas com sucesso para o filme: Saltburn
#
# Processando filme 14: Killers of the Flower Moon
# Informações adicionadas com sucesso para o filme: Killers of the Flower Moon
#
# Processando filme 15: Indiana Jones and the Dial of Destiny
# Informações adicionadas com sucesso para o filme: Indiana Jones and the Dial of Destiny
#
# Processando filme 16: Transformers: Revenge of the Fallen
# Informações adicionadas com sucesso para o filme: Transformers: Revenge of the Fallen
#
# Processando filme 17: Transformers: Dark of the Moon
# Informações adicionadas com sucesso para o filme: Transformers: Dark of the Moon
#
# Processando filme 18: Transformers: Age of Extinction
# Informações adicionadas com sucesso para o filme: Transformers: Age of Extinction
#
# Processando filme 19: Transformers: The Last Knight
# Informações adicionadas com sucesso para o filme: Transformers: The Last Knight
#
# Processando filme 20: Bumblebee
# Informações adicionadas com sucesso para o filme: Bumblebee
#
# Processando filme 21: Transformers: Rise of the Beasts
# Informações adicionadas com sucesso para o filme: Transformers: Rise of the Beasts
#
# Processando filme 22: Asteroid City
# Informações adicionadas com sucesso para o filme: Asteroid City
#
# Processando filme 23: Challengers
# Informações adicionadas com sucesso para o filme: Challengers
#
# Processando filme 24: Creed
# Informações adicionadas com sucesso para o filme: Creed
#
# Processando filme 25: Creed III
# Informações adicionadas com sucesso para o filme: Creed III
#
# Processando filme 26: Creed II
# Informações adicionadas com sucesso para o filme: Creed II
#
# Processando filme 27: John Wick: Chapter 4
# Informações adicionadas com sucesso para o filme: John Wick: Chapter 4
#
# Processando filme 28: Avatar: The Way of Water
# Informações adicionadas com sucesso para o filme: Avatar: The Way of Water
#
# Processando filme 29: Enola Holmes 2
# Informações adicionadas com sucesso para o filme: Enola Holmes 2
#
# Processando filme 30: What Is a Woman?
# Informações adicionadas com sucesso para o filme: What Is a Woman?
#
# Processando filme 31: Top Gun: Maverick
# Informações adicionadas com sucesso para o filme: Top Gun: Maverick
#
# Processando filme 32: The Northman
# Informações adicionadas com sucesso para o filme: The Northman
#
# Processando filme 33: Fantastic Beasts: The Secrets of Dumbledore
# Informações adicionadas com sucesso para o filme: Fantastic Beasts: The Secrets of Dumbledore
#
# Processando filme 34: The Last Duel
# Informações adicionadas com sucesso para o filme: The Last Duel
#
# Processando filme 35: CODA
# Informações adicionadas com sucesso para o filme: CODA
#
# Processando filme 36: The Power of the Dog
# Informações adicionadas com sucesso para o filme: The Power of the Dog
#
# Processando filme 37: The Woman in the Window
# Informações adicionadas com sucesso para o filme: The Woman in the Window
#
# Processando filme 38: Judas and the Black Messiah
# Informações adicionadas com sucesso para o filme: Judas and the Black Messiah
#
# Processando filme 39: The Invisible Man
# Informações adicionadas com sucesso para o filme: The Invisible Man
#
# Processando filme 40: Fast & Furious Presents: Hobbs & Shaw
# Informações adicionadas com sucesso para o filme: Fast & Furious Presents: Hobbs & Shaw
#
# Processando filme 41: BlacKkKlansman
# Informações adicionadas com sucesso para o filme: BlacKkKlansman
#
# Processando filme 42: The Shape of Water
# Informações adicionadas com sucesso para o filme: The Shape of Water
#
# Processando filme 43: No Country for Old Men
# Informações adicionadas com sucesso para o filme: No Country for Old Men
#
# Processando filme 44: Before the Devil Knows You're Dead
# Informações adicionadas com sucesso para o filme: Before the Devil Knows You're Dead
#
# Processando filme 45: The Aviator
# Informações adicionadas com sucesso para o filme: The Aviator
#
# Processando filme 46: The Green Mile
# Informações adicionadas com sucesso para o filme: The Green Mile
#
# Processando filme 47: Saving Private Ryan
# Informações adicionadas com sucesso para o filme: Saving Private Ryan
#
# Processando filme 48: The Omen
# Informações adicionadas com sucesso para o filme: The Omen
#
# Processando filme 49: 2001: A Space Odyssey
# Informações adicionadas com sucesso para o filme: 2001: A Space Odyssey
#
# Processando filme 50: Eternal Sunshine of the Spotless Mind
# Informações adicionadas com sucesso para o filme: Eternal Sunshine of the Spotless Mind
#
# Processando filme 51: Immaculate
# Informações adicionadas com sucesso para o filme: Immaculate
#
# Processando filme 52: Oddity
# Informações adicionadas com sucesso para o filme: Oddity
#
# Processando filme 53: Trap
# Informações adicionadas com sucesso para o filme: Trap
#
# Processando filme 54: Kinds of Kindness
# Informações adicionadas com sucesso para o filme: Kinds of Kindness
#
# Processando filme 55: Blink Twice
# Informações adicionadas com sucesso para o filme: Blink Twice
#
# Processando filme 56: Speak No Evil
# Informações adicionadas com sucesso para o filme: Speak No Evil
#
# Processando filme 57: It's What's Inside
# Informações adicionadas com sucesso para o filme: It's What's Inside
#
# Processando filme 58: Smile
# Informações adicionadas com sucesso para o filme: Smile
#
# Processando filme 59: Smile 2
# Informações adicionadas com sucesso para o filme: Smile 2
#
# Processando filme 60: Tenet
# Informações adicionadas com sucesso para o filme: Tenet
#
# Processando filme 61: Junior
# Informações adicionadas com sucesso para o filme: Junior
#
# Processando filme 62: The Black Phone
# Informações adicionadas com sucesso para o filme: The Black Phone
#
# Processando filme 63: The Shawshank Redemption
# Informações adicionadas com sucesso para o filme: The Shawshank Redemption
#
# Processando filme 64: 12 Angry Men
# Informações adicionadas com sucesso para o filme: 12 Angry Men
#
# Processando filme 65: One Flew Over the Cuckoo's Nest
# Informações adicionadas com sucesso para o filme: One Flew Over the Cuckoo's Nest
#
# Processando filme 66: The Good, the Bad and the Ugly
# Informações adicionadas com sucesso para o filme: The Good, the Bad and the Ugly
#
# Processando filme 67: Once Upon a Time in the West
# Informações adicionadas com sucesso para o filme: Once Upon a Time in the West
#
# Processando filme 68: The Silence of the Lambs
# Informações adicionadas com sucesso para o filme: The Silence of the Lambs
#
# Processando filme 69: Psycho
# Informações adicionadas com sucesso para o filme: Psycho
#
# Processando filme 70: Sunset Boulevard
# Informações adicionadas com sucesso para o filme: Sunset Boulevard
#
# Processando filme 71: Gladiator
# Informações adicionadas com sucesso para o filme: Gladiator
#
# Processando filme 72: Léon: The Professional
# Informações adicionadas com sucesso para o filme: Léon: The Professional
#
# Processando filme 73: The Pianist
# Informações adicionadas com sucesso para o filme: The Pianist
#
# Processando filme 74: The Great Escape
# Informações adicionadas com sucesso para o filme: The Great Escape
#
# Processando filme 75: Apocalypse Now
# Informações adicionadas com sucesso para o filme: Apocalypse Now
#
# Processando filme 76: Citizen Kane
# Informações adicionadas com sucesso para o filme: Citizen Kane
#
# Processando filme 77: Vertigo
# Informações adicionadas com sucesso para o filme: Vertigo
#
# Processando filme 78: The Hunt
# Informações adicionadas com sucesso para o filme: The Hunt
#
# Processando filme 79: Django Unchained
# Informações adicionadas com sucesso para o filme: Django Unchained
#
# Processando filme 80: Love Lies Bleeding
# Informações adicionadas com sucesso para o filme: Love Lies Bleeding
#
# Processando filme 81: Taxi Driver
# Informações adicionadas com sucesso para o filme: Taxi Driver
#
# Processando filme 82: Casino
# Informações adicionadas com sucesso para o filme: Casino
#
# Processando filme 83: Reservoir Dogs
# Informações adicionadas com sucesso para o filme: Reservoir Dogs
#
# Processando filme 84: The Celebration
# Informações adicionadas com sucesso para o filme: The Celebration
#
# Processando filme 85: Moonlight
# Informações adicionadas com sucesso para o filme: Moonlight
#
# Processando filme 86: Hereditary
# Informações adicionadas com sucesso para o filme: Hereditary
#
# Processando filme 87: Horizon: An American Saga - Chapter 2
# Informações adicionadas com sucesso para o filme: Horizon: An American Saga - Chapter 2
#
# Processando filme 88: Nymphomaniac: Vol. I
# Informações adicionadas com sucesso para o filme: Nymphomaniac: Vol. I
#
# Processando filme 89: The Ballad of Buster Scruggs
# Informações adicionadas com sucesso para o filme: The Ballad of Buster Scruggs
#
# Processando filme 90: Gladiator II
# Informações adicionadas com sucesso para o filme: Gladiator II
#
# Processando filme 91: A Real Pain
# Informações adicionadas com sucesso para o filme: A Real Pain
#
# Processando filme 92: The Menu
# Informações adicionadas com sucesso para o filme: The Menu
#
# Processando filme 93: Birdman or (The Unexpected Virtue of Ignorance)
# Informações adicionadas com sucesso para o filme: Birdman or (The Unexpected Virtue of Ignorance)
#
# Processando filme 94: Space Cowboys
# Informações adicionadas com sucesso para o filme: Space Cowboys
#
# Processando filme 95: RoboCop
# Informações adicionadas com sucesso para o filme: RoboCop
#
# Processando filme 96: Sonic the Hedgehog 3
# Informações adicionadas com sucesso para o filme: Sonic the Hedgehog 3
#
# Processando filme 97: Die Hard
# Informações adicionadas com sucesso para o filme: Die Hard
#
# Processando filme 98: Basic Instinct
# Informações adicionadas com sucesso para o filme: Basic Instinct
#
# Processando filme 99: The Deer Hunter
# Informações adicionadas com sucesso para o filme: The Deer Hunter
#
# Processando filme 100: Million Dollar Baby
# Informações adicionadas com sucesso para o filme: Million Dollar Baby
#
# Processando filme 101: Juror #2
# Informações adicionadas com sucesso para o filme: Juror #2
#
# Processando filme 102: Babygirl
# Informações adicionadas com sucesso para o filme: Babygirl
#
# Processando filme 103: Blade Runner
# Informações adicionadas com sucesso para o filme: Blade Runner
#
# Processando filme 104: Blade Runner 2049
# Informações adicionadas com sucesso para o filme: Blade Runner 2049
#
# Processando filme 105: Falsa Loura
# Informações adicionadas com sucesso para o filme: Falsa Loura
#
# Processando filme 106: Jackie Brown
# Informações adicionadas com sucesso para o filme: Jackie Brown
#
# Processando filme 107: Mulholland Drive
# Informações adicionadas com sucesso para o filme: Mulholland Drive
#
# Processando filme 108: Zodiac
# Informações adicionadas com sucesso para o filme: Zodiac
#
# Processando filme 109: The Game
# Informações adicionadas com sucesso para o filme: The Game
#
# Processando filme 110: The Apartment
# Informações adicionadas com sucesso para o filme: The Apartment
#
# Processando filme 111: Companion
# Informações adicionadas com sucesso para o filme: Companion
#
# Processando filme 112: The Batman
# Informações adicionadas com sucesso para o filme: The Batman
#
# Processando filme 113: Rocky II
# Informações adicionadas com sucesso para o filme: Rocky II
#
# Processando filme 114: Rocky III
# Informações adicionadas com sucesso para o filme: Rocky III
#
# Processando filme 115: Big
# Informações adicionadas com sucesso para o filme: Big
#
# Processando filme 116: The Godfather
# Informações adicionadas com sucesso para o filme: The Godfather
#
# Processando filme 117: The Godfather Part II
# Informações adicionadas com sucesso para o filme: The Godfather Part II
#
# Processando filme 118: The Godfather Part III
# Informações adicionadas com sucesso para o filme: The Godfather Part III
#
# Processando filme 119: Dolemite Is My Name
# Informações adicionadas com sucesso para o filme: Dolemite Is My Name
#
# Processando filme 120: The Trial of the Chicago 7
# Informações adicionadas com sucesso para o filme: The Trial of the Chicago 7
#
# Processando filme 121: Schindler's List
# Informações adicionadas com sucesso para o filme: Schindler's List
#
# Processando filme 122: Once Upon a Time... in Hollywood
# Informações adicionadas com sucesso para o filme: Once Upon a Time... in Hollywood
#
# Processando filme 123: The Shining
# Informações adicionadas com sucesso para o filme: The Shining
#
# Processando filme 124: Christine
# Informações adicionadas com sucesso para o filme: Christine
#
# Processando filme 125: Back to the Future
# Informações adicionadas com sucesso para o filme: Back to the Future
#
# Processando filme 126: Back to the Future Part II
# Informações adicionadas com sucesso para o filme: Back to the Future Part II
#
# Processando filme 127: Back to the Future Part III
# Informações adicionadas com sucesso para o filme: Back to the Future Part III
#
# Processando filme 128: Bad Boys
# Informações adicionadas com sucesso para o filme: Bad Boys
#
# Processando filme 129: Bad Boys II
# Informações adicionadas com sucesso para o filme: Bad Boys II
#
# Processando filme 130: Bad Boys for Life
# Informações adicionadas com sucesso para o filme: Bad Boys for Life
#
# Processando filme 131: Knives Out
# Informações adicionadas com sucesso para o filme: Knives Out
#
# Processando filme 132: Dallas Buyers Club
# Informações adicionadas com sucesso para o filme: Dallas Buyers Club
#
# Processando filme 133: The Others
# Informações adicionadas com sucesso para o filme: The Others
#
# Processando filme 134: They Live
# Informações adicionadas com sucesso para o filme: They Live
#
# Processando filme 135: Halloween
# Informações adicionadas com sucesso para o filme: Halloween
#
# Processando filme 136: Under the Silver Lake
# Informações adicionadas com sucesso para o filme: Under the Silver Lake
#
# Processando filme 137: Midnight in Paris
# Informações adicionadas com sucesso para o filme: Midnight in Paris
#
# Processando filme 138: The Big Short
# Informações adicionadas com sucesso para o filme: The Big Short
#
# Processando filme 139: Incendies
# Informações adicionadas com sucesso para o filme: Incendies
#
# Processando filme 140: Sicario
# Informações adicionadas com sucesso para o filme: Sicario
#
# Processando filme 141: Central Station
# Informações adicionadas com sucesso para o filme: Central Station
#
# Processando filme 142: American History X
# Informações adicionadas com sucesso para o filme: American History X
#
# Processando filme 143: Nickel Boys
# Informações adicionadas com sucesso para o filme: Nickel Boys
#
# Processando filme 144: Malu
# Informações adicionadas com sucesso para o filme: Malu
#
# Processando filme 145: Sicario: Day of the Soldado
# Informações adicionadas com sucesso para o filme: Sicario: Day of the Soldado
#
# Processando filme 146: Rio, 40 Degrees
# Informações adicionadas com sucesso para o filme: Rio, 40 Degrees
#
# Processando filme 147: Blow Out
# Informações adicionadas com sucesso para o filme: Blow Out
#
# Processando filme 148: True Crime
# Informações adicionadas com sucesso para o filme: True Crime
#
# Processando filme 149: The Alto Knights
# Informações adicionadas com sucesso para o filme: The Alto Knights
#
# Processando filme 150: Once Upon a Time in America
# Informações adicionadas com sucesso para o filme: Once Upon a Time in America
#
# Processando filme 151: Persona
# Informações adicionadas com sucesso para o filme: Persona
#
# Processando filme 152: Stalker
# Informações adicionadas com sucesso para o filme: Stalker
#
# Processando filme 153: The Secret Agent
# Informações adicionadas com sucesso para o filme: The Secret Agent
#
# Processando filme 154: Ballerina
# Informações adicionadas com sucesso para o filme: Ballerina
#
# Processando filme 155: F1: The Movie
# Informações adicionadas com sucesso para o filme: F1: The Movie
#
# Processando filme 156: Happy Gilmore
# Informações adicionadas com sucesso para o filme: Happy Gilmore
#
# Processando filme 157: Vitória
# Informações adicionadas com sucesso para o filme: Vitória
#
# Processando filme 158: The Terminal
# Informações adicionadas com sucesso para o filme: The Terminal
#
# Processando filme 159: We Need to Talk About Kevin
# Informações adicionadas com sucesso para o filme: We Need to Talk About Kevin
#
# Processando filme 160: Happy Gilmore 2
# Informações adicionadas com sucesso para o filme: Happy Gilmore 2
#
# Processando filme 161: Being John Malkovich
# Informações adicionadas com sucesso para o filme: Being John Malkovich
#
# Processando filme 162: Raising Cain
# Informações adicionadas com sucesso para o filme: Raising Cain
#
# Processando filme 163: The Blue Trail
#
#  ******** Título não corresponde ou não encontrado: The Blue Trail != N/A *******
#
# Processando filme 164: Eddington
# Informações adicionadas com sucesso para o filme: Eddington
#
# Processando filme 165: Manas
# Informações adicionadas com sucesso para o filme: Manas
#
# Processando filme 166: The Hateful Eight
# Informações adicionadas com sucesso para o filme: The Hateful Eight
#
# Processando filme 167: Thief
# Informações adicionadas com sucesso para o filme: Thief
#
# Processando filme 168: After Hours
# Informações adicionadas com sucesso para o filme: After Hours
#
# Processando filme 169: Gangs of New York
# Informações adicionadas com sucesso para o filme: Gangs of New York
#
# Processando filme 170: Cape Fear
# Informações adicionadas com sucesso para o filme: Cape Fear
#
# Processando filme 171: Requiem for a Dream
# Informações adicionadas com sucesso para o filme: Requiem for a Dream
#
# Processando filme 172: Hard Labor
# Informações adicionadas com sucesso para o filme: Hard Labor
#
# Processando filme 173: The Red Light Bandit
# Informações adicionadas com sucesso para o filme: The Red Light Bandit
#
# Processando filme 174: Black Phone 2
# Informações adicionadas com sucesso para o filme: Black Phone 2
#
# Processando filme 175: Lord of War
# Informações adicionadas com sucesso para o filme: Lord of War
#
# Processando filme 176: Deep End
# Informações adicionadas com sucesso para o filme: Deep End
#
# Processando filme 177: A Nightmare on Elm Street
# Informações adicionadas com sucesso para o filme: A Nightmare on Elm Street
#
# Processando filme 178: I Love You Phillip Morris
# Informações adicionadas com sucesso para o filme: I Love You Phillip Morris
#
# Processando filme 179: Good Boy
# Informações adicionadas com sucesso para o filme: Good Boy
#
# Processando filme 180: The Texas Chain Saw Massacre
# Informações adicionadas com sucesso para o filme: The Texas Chain Saw Massacre
#
# Processando filme 181: The Blair Witch Project
# Informações adicionadas com sucesso para o filme: The Blair Witch Project
#
# Processando filme 182: Inferno
# Informações adicionadas com sucesso para o filme: Inferno
#
# Processando filme 183: Friday the 13th
# Informações adicionadas com sucesso para o filme: Friday the 13th
#
# Processando filme 184: The Witch
# Informações adicionadas com sucesso para o filme: The Witch
#
# Processando filme 185: Carrie
# Informações adicionadas com sucesso para o filme: Carrie
#
# Processando filme 186: Bugonia
# Informações adicionadas com sucesso para o filme: Bugonia
#
# Processando filme 187: Speed
# Informações adicionadas com sucesso para o filme: Speed
#
# Processando filme 188: Dog Day Afternoon
# Informações adicionadas com sucesso para o filme: Dog Day Afternoon
#
# Processando filme 189: Memories of Murder
# Informações adicionadas com sucesso para o filme: Memories of Murder

# %% [markdown]
# Saving the df

# %%
watchlist_df.to_csv(watchlist_path, index=False)

# %% [markdown]
# Separate decades presents in watchlist

# %%
def separate_movie_by_decade(newest_df):
    decades = {}
    min_year = newest_df["Year"].min()
    max_year = newest_df["Year"].max()
    aux_min_year = min_year

    for i in range(min_year, max_year + 1):
        if i % 10 == 0:
            aux_max_year = i
            decades[f"{aux_min_year}-{aux_max_year}"] = [None]
            aux_min_year = i + 1

    decades[f"{aux_min_year}-{max_year}"] = [None]

    return decades

# %%
from collections import Counter

def separate_topics(watchlist_df, topic):

    list_topics = []
    aux = []
    for item in watchlist_df[topic]:
        if pd.notna(item):
            list_topics.append(item.split(", "))

    for p in list_topics:
        for word in p:
            aux.append(word)

    return dict(Counter(aux).most_common(5))

# %%
decades = separate_movie_by_decade(watchlist_df)

for key in decades.keys():
    ini = key[:4]
    end = key[5:]
    aux_list = []

    for i in range(int(ini) , int(end) + 1):
        n = watchlist_df[watchlist_df["Year"] == i]["Name"]
        for info in n:
            aux_list.append(info)
    decades[key] = aux_list

for key, value in decades.items():
    print(f"\n{key}: {value}\n")
    print("="*130)
# Out:
# 1941-1950: ['Citizen Kane', 'Sunset Boulevard']
#
# ==================================================================================================================================
#
# 1951-1960: ['Rio, 40 Degrees', '12 Angry Men', 'Vertigo', 'Psycho', 'The Apartment']
#
# ==================================================================================================================================
#
# 1961-1970: ['The Great Escape', 'The Good, the Bad and the Ugly', 'Persona', 'Planet of the Apes', '2001: A Space Odyssey', 'Once Upon a Time in the West', 'The Red Light Bandit', 'Deep End']
#
# ==================================================================================================================================
#
# 1971-1980: ['The Godfather', 'The Godfather Part II', 'The Texas Chain Saw Massacre', "One Flew Over the Cuckoo's Nest", 'Dog Day Afternoon', 'The Omen', 'Taxi Driver', 'Carrie', 'The Deer Hunter', 'Halloween', 'Apocalypse Now', 'Rocky II', 'Stalker', 'The Shining', 'Inferno', 'Friday the 13th']
#
# ==================================================================================================================================
#
# 1981-1990: ['Blow Out', 'Thief', 'Blade Runner', 'Rocky III', 'Christine', 'Once Upon a Time in America', 'A Nightmare on Elm Street', 'Back to the Future', 'After Hours', 'RoboCop', 'Die Hard', 'Big', 'They Live', 'Back to the Future Part II', 'The Godfather Part III', 'Back to the Future Part III']
#
# ==================================================================================================================================
#
# 1991-2000: ['The Silence of the Lambs', 'Cape Fear', 'Reservoir Dogs', 'Basic Instinct', 'Raising Cain', "Schindler's List", 'Junior', 'The Shawshank Redemption', 'Léon: The Professional', 'Speed', 'Casino', 'Bad Boys', 'Happy Gilmore', 'Jackie Brown', 'The Game', 'Saving Private Ryan', 'The Celebration', 'Central Station', 'American History X', 'The Green Mile', 'True Crime', 'Being John Malkovich', 'The Blair Witch Project', 'Gladiator', 'Space Cowboys', 'Requiem for a Dream']
#
# ==================================================================================================================================
#
# 2001-2010: ['Mulholland Drive', 'The Others', 'The Pianist', 'Gangs of New York', 'Bad Boys II', 'Memories of Murder', 'The Aviator', 'Eternal Sunshine of the Spotless Mind', 'Million Dollar Baby', 'The Terminal', 'Lord of War', 'No Country for Old Men', "Before the Devil Knows You're Dead", 'Falsa Loura', 'Zodiac', 'Transformers: Revenge of the Fallen', 'I Love You Phillip Morris', 'Inception', 'Incendies']
#
# ==================================================================================================================================
#
# 2011-2020: ['Transformers: Dark of the Moon', 'Midnight in Paris', 'We Need to Talk About Kevin', 'Hard Labor', 'The Hunt', 'Django Unchained', 'The Wolf of Wall Street', 'Nymphomaniac: Vol. I', 'Dallas Buyers Club', 'Transformers: Age of Extinction', 'Birdman or (The Unexpected Virtue of Ignorance)', 'Creed', 'The Big Short', 'Sicario', 'The Hateful Eight', 'The Witch', 'Moonlight', 'Transformers: The Last Knight', 'The Shape of Water', 'Blade Runner 2049', 'Bumblebee', 'Creed II', 'BlacKkKlansman', 'Hereditary', 'The Ballad of Buster Scruggs', 'Under the Silver Lake', 'Sicario: Day of the Soldado', 'Fast & Furious Presents: Hobbs & Shaw', 'Dolemite Is My Name', 'Once Upon a Time... in Hollywood', 'Knives Out', 'The Invisible Man', 'Tenet', 'The Trial of the Chicago 7', 'Bad Boys for Life']
#
# ==================================================================================================================================
#
# 2021-2025: ['The Last Duel', 'CODA', 'The Power of the Dog', 'The Woman in the Window', 'Judas and the Black Messiah', 'The Black Phone', 'Glass Onion', 'Avatar: The Way of Water', 'Enola Holmes 2', 'What Is a Woman?', 'Top Gun: Maverick', 'The Northman', 'Fantastic Beasts: The Secrets of Dumbledore', 'Smile', 'The Menu', 'The Batman', 'The Holdovers', 'Godzilla Minus One', 'Oppenheimer', 'American Fiction', 'Anatomy of a Fall', 'Past Lives', 'Saltburn', 'Killers of the Flower Moon', 'Indiana Jones and the Dial of Destiny', 'Transformers: Rise of the Beasts', 'Asteroid City', 'Creed III', 'John Wick: Chapter 4', 'Bad Boys: Ride or Die', 'Ghostbusters: Frozen Empire', 'Madame Web', 'Challengers', 'Immaculate', 'Oddity', 'Trap', 'Kinds of Kindness', 'Blink Twice', 'Speak No Evil', "It's What's Inside", 'Smile 2', 'Love Lies Bleeding', 'Horizon: An American Saga - Chapter 2', 'Gladiator II', 'A Real Pain', 'Sonic the Hedgehog 3', 'Juror #2', 'Babygirl', 'Nickel Boys', 'Malu', 'Manas', 'Companion', 'The Alto Knights', 'The Secret Agent', 'Ballerina', 'F1: The Movie', 'Vitória', 'Happy Gilmore 2', 'The Blue Trail', 'Eddington', 'Black Phone 2', 'Good Boy', 'Bugonia']
#
# ==================================================================================================================================

# %% [markdown]
# Number of movies by decade

# %%
number_decade = {}

for key in decades.keys():
    number_decade[key] = len(decades[key])

for key, value in number_decade.items():
    print(f"{key}: {value} movies")
# Out:
# 1941-1950: 2 movies
# 1951-1960: 5 movies
# 1961-1970: 8 movies
# 1971-1980: 16 movies
# 1981-1990: 16 movies
# 1991-2000: 26 movies
# 2001-2010: 19 movies
# 2011-2020: 35 movies
# 2021-2025: 63 movies

# %% [markdown]
# Separating movies of a especific decade

# %%
def films_by_decade(dict, year):
    year += 1
    for key in dict.keys():
        if key.startswith(str(year)):
            return dict[key]

    return f"Invalid year or movies not found for {year} decade"

# %% [markdown]
# Choosing a film randomly using decade

# %%
import random
print(f"The movie is => {random.choice(films_by_decade(decades, 1940))}")
# Out:
# The movie is => Citizen Kane

# %% [markdown]
# Top 5 directors in watchlist

# %%
#print(watchlist_df["Director"].value_counts().head(5).to_string())
for director, value in separate_topics(watchlist_df, "Director").items():
    print(f"{director} -> {value} movies")
# Out:
# Martin Scorsese -> 8 movies
# Michael Bay -> 6 movies
# Quentin Tarantino -> 5 movies
# Ridley Scott -> 4 movies
# Francis Ford Coppola -> 4 movies

# %% [markdown]
# Top 5 years in watchlist

# %%
print(watchlist_df["Year"].value_counts().head(5).to_string())
# Out:
# Year
# 2024    22
# 2023    13
# 2025    12
# 2022    10
# 2018     7

# %%
for genre, value in separate_topics(watchlist_df, "Genre").items():
    print(f"{genre} -> {value} movies")
# Out:
# Drama -> 121 movies
# Crime -> 54 movies
# Comedy -> 44 movies
# Action -> 43 movies
# Thriller -> 39 movies

# %% [markdown]
# Top 5 actors in watchlist

# %%
for actor, value in separate_topics(watchlist_df, "Actors").items():
    print(f"{actor} -> {value} movies")
# Out:
# Robert De Niro -> 8 movies
# Leonardo DiCaprio -> 7 movies
# Tom Hanks -> 6 movies
# Sylvester Stallone -> 4 movies
# Keanu Reeves -> 4 movies

# %% [markdown]
# Top 5 Countries in watchlist

# %%
for country, value in separate_topics(watchlist_df, "Country").items():
    print(f"{country} -> {value} movies")
# Out:
# United States -> 169 movies
# United Kingdom -> 31 movies
# Canada -> 15 movies
# France -> 15 movies
# China -> 7 movies

# %% [markdown]
# Top 5 languages in watchlist

# %%
for language, value in separate_topics(watchlist_df, "Language").items():
    print(f"{language} -> {value} movies")
# Out:
# English -> 179 movies
# Spanish -> 37 movies
# French -> 32 movies
# German -> 23 movies
# Italian -> 21 movies
